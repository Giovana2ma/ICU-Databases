# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import gc
from tqdm import tqdm

# %% [markdown]
# ## Bases

# %%
BASES_HOSP = "/scratch/haniel.botelho/physionet.org/files/mimiciv/2.2/hosp/"
BASES_ICU = "/scratch/haniel.botelho/physionet.org/files/mimiciv/2.2/icu/"
labexams = "labevents.csv"
chartexams = "chartevents.csv"
omr = "omr.csv"
microbiologyevents = "microbiologyevents.csv"
pharmacy = "pharmacy.csv"
emar = "emar.csv"
prescriptions = "prescriptions.csv"
procedures = "procedures_icd.csv"
d_labitems = "d_labitems.csv"
d_items = "d_items.csv"
d_procedures= "d_icd_procedures.csv"

path_lab = BASES_HOSP + labexams
path_chart = BASES_ICU + chartexams
path_ids_labs = BASES_HOSP + d_labitems
path_ids_items = BASES_ICU + d_items
path_omr = BASES_HOSP + omr
path_microbiology = BASES_HOSP + microbiologyevents
path_pharmacy = BASES_HOSP + pharmacy
path_emar = BASES_HOSP + emar
path_prescriptions = BASES_HOSP + prescriptions
path_procedures = BASES_HOSP + procedures
path_d_procedures = BASES_HOSP + d_procedures

# %%
def create_summary_table(data: pd.DataFrame, include_ref_range: bool) -> pd.DataFrame:
    # Definir as agregações básicas
    aggregations = {
        'itemid': 'count',
        'valuenum': [ 'max', 'min'],
        'valueuom': 'first',
    }
    
    # Adicionar as colunas ref_range_lower e ref_range_upper se necessário
    if include_ref_range:
        aggregations['ref_range_lower'] = 'first'
        aggregations['ref_range_upper'] = 'first'

    summary_table = data.groupby('itemid').agg(aggregations).reset_index()

    # Renomear as colunas para facilitar a leitura
    col_names = ['itemid', 'count', 'max_valuenum', 'min_valuenum', 'valueuom']
    if include_ref_range:
        col_names += ['ref_range_lower', 'ref_range_upper']
    summary_table.columns = col_names

    return summary_table

# %%
# procedures = pd.read_csv(path_procedures)
prescriptions = pd.read_csv(path_prescriptions)
# pharmacy = pd.read_csv(path_pharmacy)
# emar = pd.read_csv(path_emar)
# microbiology = pd.read_csv(path_microbiology)
# omr = pd.read_csv(path_omr)
# d_procedures = pd.read_csv(path_d_procedures)
# Out:
# /tmp/ipykernel_344988/447445098.py:2: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   prescriptions = pd.read_csv(path_prescriptions)

# %% [markdown]
# ## Prescriptions

# %%
prescriptions
# Out:
#           subject_id   hadm_id  pharmacy_id        poe_id  poe_seq  \
# 0           10000032  22595853     11700683   10000032-34     34.0
# 1           10000032  22595853     14779570   10000032-22     22.0
# 2           10000032  22595853     19796602   10000032-50     50.0
# 3           10000032  22595853     20256254   10000032-32     32.0
# 4           10000032  22595853     28781051   10000032-27     27.0
# ...              ...       ...          ...           ...      ...
# 15416703    19999987  23865745     92839339   19999987-25     25.0
# 15416704    19999987  23865745     92913309  19999987-150    150.0
# 15416705    19999987  23865745     95753195  19999987-219    219.0
# 15416706    19999987  23865745     96343043  19999987-206    206.0
# 15416707    19999987  23865745     98044699  19999987-207    207.0
#
#          order_provider_id            starttime             stoptime  \
# 0                   P76JEQ  2180-05-07 01:00:00  2180-05-07 22:00:00
# 1                   P76JEQ  2180-05-07 00:00:00  2180-05-07 22:00:00
# 2                   P260SK  2180-05-08 08:00:00  2180-05-07 22:00:00
# 3                   P76JEQ  2180-05-07 01:00:00  2180-05-07 22:00:00
# 4                   P76JEQ  2180-05-07 00:00:00  2180-05-07 22:00:00
# ...                    ...                  ...                  ...
# 15416703            P5542X  2145-11-03 00:00:00  2145-11-03 18:00:00
# 15416704            P63OX3  2145-11-04 10:00:00  2145-11-11 17:00:00
# 15416705            P77Z1Y  2145-11-10 10:00:00  2145-11-11 17:00:00
# 15416706            P77Z1Y  2145-11-09 10:00:00  2145-11-09 16:00:00
# 15416707            P77Z1Y  2145-11-09 10:00:00  2145-11-09 16:00:00
#
#          drug_type                         drug  ...      gsn           ndc  \
# 0             MAIN                Acetaminophen  ...   004490  9.041989e+08
# 1             MAIN  Sodium Chloride 0.9%  Flush  ...      NaN  0.000000e+00
# 2             MAIN                   Furosemide  ...   008209  5.107901e+10
# 3             MAIN                  Raltegravir  ...   063231  6.022761e+06
# 4             MAIN                      Heparin  ...   006549  6.332303e+10
# ...            ...                          ...  ...      ...           ...
# 15416703      MAIN      Influenza Virus Vaccine  ...  69637.0  3.333200e+10
# 15416704      MAIN         Levothyroxine Sodium  ...   6649.0  7.445521e+07
# 15416705      MAIN                   Duloxetine  ...  57892.0  2.324033e+06
# 15416706      MAIN               Venlafaxine XR  ...  46405.0  6.808405e+10
# 15416707      MAIN                   Duloxetine  ...  57892.0  2.324033e+06
#
#                       prod_strength form_rx dose_val_rx dose_unit_rx  \
# 0                      500mg Tablet     NaN         500           mg
# 1                     10 mL Syringe     NaN           3           mL
# 2                       40mg Tablet     NaN          40           mg
# 3                     400 mg Tablet     NaN         400           mg
# 4         5000 Units / mL- 1mL Vial     NaN        5000         UNIT
# ...                             ...     ...         ...          ...
# 15416703             0.5 mL Syringe     NaN         0.5           mL
# 15416704               50mcg Tablet     NaN          50          mcg
# 15416705               30mg Capsule     NaN          60           mg
# 15416706           150mg XR Capsule     NaN         150           mg
# 15416707               30mg Capsule     NaN          60           mg
#
#          form_val_disp form_unit_disp doses_per_24_hrs  route
# 0                    1            TAB              NaN  PO/NG
# 1                  0.3            SYR              3.0     IV
# 2                    1            TAB              1.0  PO/NG
# 3                    1            TAB              2.0     PO
# 4                    1             mL              3.0     SC
# ...                ...            ...              ...    ...
# 15416703             1            SYR              0.0     IM
# 15416704             1            TAB              1.0  PO/NG
# 15416705             2            CAP              1.0     PO
# 15416706             1            CAP              1.0     PO
# 15416707             2            CAP              1.0     PO
#
# [15416708 rows x 21 columns]

# %%
len(prescriptions[prescriptions['route'].notna()]['route'])
# Out:
# 15412808

# %%
prescriptions['route'].notna()
# Out:
# 0           True
# 1           True
# 2           True
# 3           True
# 4           True
#             ...
# 15416703    True
# 15416704    True
# 15416705    True
# 15416706    True
# 15416707    True
# Name: route, Length: 15416708, dtype: bool

# %%
summary_prescriptions = prescriptions.groupby('drug').agg({
        'subject_id': 'count',
        'dose_unit_rx': 'first',
        'ndc': 'first',
    }).reset_index()
summary_prescriptions.columns = ['Nome','Quantidade','Unidade','NomeFormal']
summary_prescriptions
# Out:
#                                                   Nome  Quantidade   Unidade  \
# 0                                  Adcirca (tadalafil)           1        mg
# 1                        Autologus Serum Eye Drops 20%           1      DROP
# 2                                        CoQ10 (300mg)           2  mg\ 0 mg
# 3      Endocet *NF* (oxyCODONE-acetaminophen) 1/2 TAB            1       TAB
# 4                                Enzalutamide (Xtandi)           1        mg
# ...                                                ...         ...       ...
# 9608                                             zypre           1        mg
# 9609                                          zyrtec-D           1        mg
# 9610                                                zz           4       mcg
# 9611                                    zzVoxtalisibzz           1        mg
# 9612                                        ~Rituximab           1        mg
#
#         NomeFormal
# 0              NaN
# 1              NaN
# 2     1.465408e+10
# 3              NaN
# 4              NaN
# ...            ...
# 9608  2.445385e+06
# 9609           NaN
# 9610  0.000000e+00
# 9611  0.000000e+00
# 9612  5.024201e+10
#
# [9613 rows x 4 columns]

# %% [markdown]
# ## Procedures

# %%
procedures = procedures.merge(d_procedures,on='icd_code')
summary_procedures = procedures.groupby('long_title')['subject_id'].count().reset_index()
summary_procedures.columns = ['Nome', 'Quantidade']
summary_procedures

# %% [markdown]
# ## Pharmacy

# %%
summary_pharmacy = pharmacy.groupby('medication')['subject_id'].count().reset_index()
summary_pharmacy.columns = ['Nome', 'Quantidade']
summary_pharmacy

# %% [markdown]
# ## Emar

# %%
summary_emar = emar.groupby('medication')['subject_id'].count().reset_index()
summary_emar.columns = ['Nome', 'Quantidade']
summary_emar
# Out:
#                                       Nome  Quantidade
# 0                 CoQ10 (300mg) or placebo          13
# 1                             INV-ABL001            22
# 2           Niacinamide 1g, 3g, or placebo           1
# 3      ketamine 5%/ lidocaine 5% / amit 2%          12
# 4         *NF* Carbidopa-Levodopa (25-100)          25
# ...                                    ...         ...
# 4181                zinc picolinate (bulk)           4
# 4182                          zinc sulfate          10
# 4183                       zoledronic acid           5
# 4184                              zolpidem           1
# 4185                            zonisamide          16
#
# [4186 rows x 2 columns]

# %% [markdown]
# ## Microbiology

# %%
summary_microbiology = microbiology.groupby('test_name').agg({
        'subject_id': 'count',
        'spec_type_desc': 'first'
    }).reset_index()
summary_microbiology.columns = ['Nome','Quantidade','Tipo']
summary_microbiology
# Out:
#                                         Nome  Quantidade  \
# 0                          ACID FAST CULTURE       29356
# 1                            ACID FAST SMEAR       27142
# 2                   ADDITIONAL CELLS COUNTED         101
# 3                             AEROBIC BOTTLE       10174
# 4                           ANAEROBIC BOTTLE        9759
# ..                                       ...         ...
# 166       VIRAL CULTURE: R/O CYTOMEGALOVIRUS        2213
# 167  VIRAL CULTURE: R/O HERPES SIMPLEX VIRUS        4526
# 168                            WOUND CULTURE      165671
# 169                  YEAST VAGINITIS CULTURE       19424
# 170                                   voided           3
#
#                            Tipo
# 0              PERITONEAL FLUID
# 1              PERITONEAL FLUID
# 2    BONE MARROW - CYTOGENETICS
# 3                 BLOOD CULTURE
# 4                 BLOOD CULTURE
# ..                          ...
# 166      BRONCHOALVEOLAR LAVAGE
# 167              SKIN SCRAPINGS
# 168                        SWAB
# 169                        SWAB
# 170               BLOOD CULTURE
#
# [171 rows x 3 columns]

# %% [markdown]
# ## Omr

# %%
summary_omr = omr.groupby('result_name')['subject_id'].count().reset_index()
summary_omr.columns = ['Nome', 'Quantidade']
summary_omr
# Out:
#                                 Nome  Quantidade
# 0                                BMI         554
# 1                        BMI (kg/m2)     1662112
# 2                     Blood Pressure     2169549
# 3               Blood Pressure Lying        2764
# 4             Blood Pressure Sitting        3400
# 5            Blood Pressure Standing         523
# 6    Blood Pressure Standing (1 min)        2560
# 7   Blood Pressure Standing (3 mins)         626
# 8                             Height          39
# 9                    Height (Inches)      706906
# 10                            Weight         354
# 11                      Weight (Lbs)     1889542
# 12                              eGFR         240

# %% [markdown]
# ## Exams

# %%
labexams = pd.read_csv(path_lab,usecols=['subject_id','charttime','itemid','valuenum','valueuom','ref_range_lower','ref_range_upper'])
# chartexams = pd.read_csv(path_chart,usecols=['itemid','valuenum','valueuom'])

# %%
ids_labs = pd.read_csv(path_ids_labs)
ids_items = pd.read_csv(path_ids_items)

# %%
teste = labexams[(labexams['itemid']==50912) | (labexams['itemid']==52546)]
teste[teste.duplicated(subset=['charttime','subject_id'], keep=False)].sort_values(by = ['subject_id','charttime']).to_csv('teste',index=False)

# %%
summary_lab = create_summary_table(labexams,True)
# summary_chart = create_summary_table(chartexams,False)

# %%
summary_lab = summary_lab.merge(ids_labs, on='itemid') 
# summary_lab = summary_lab.drop('itemid', axis=1)
# summary_chart = summary_chart.merge(ids_items, on='itemid') 
# summary_chart = summary_chart.drop('itemid', axis=1)

# %%
teste = labexams.dropna(subset=['valuenum'])
# Out:
#            subject_id  itemid            charttime  valuenum valueuom  \
# 0            10000032   51237  2180-03-23 11:51:00      1.40      NaN
# 1            10000032   51274  2180-03-23 11:51:00     15.10      sec
# 2            10000032   50853  2180-03-23 11:51:00     15.00    ng/mL
# 3            10000032   50861  2180-03-23 11:51:00    102.00     IU/L
# 4            10000032   50862  2180-03-23 11:51:00      3.30     g/dL
# ...               ...     ...                  ...       ...      ...
# 118171362    19999987   51279  2145-11-09 05:30:00      3.52     m/uL
# 118171363    19999987   51301  2145-11-09 05:30:00      5.70     K/uL
# 118171364    19999987   50912  2146-02-07 11:13:00      1.10    mg/dL
# 118171365    19999987   50920  2146-02-07 11:13:00       NaN      NaN
# 118171366    19999987   51006  2146-02-07 11:13:00     14.00    mg/dL
#
#            ref_range_lower  ref_range_upper
# 0                      0.9              1.1
# 1                      9.4             12.5
# 2                     30.0             60.0
# 3                      0.0             40.0
# 4                      3.5              5.2
# ...                    ...              ...
# 118171362              4.2              5.4
# 118171363              4.0             11.0
# 118171364              0.4              1.1
# 118171365              NaN              NaN
# 118171366              6.0             20.0
#
# [118171367 rows x 7 columns]

# %%
teste = labexams.dropna(subset=['valuenum'])
teste
# Out:
#            subject_id  itemid            charttime  valuenum valueuom  \
# 0            10000032   51237  2180-03-23 11:51:00      1.40      NaN
# 1            10000032   51274  2180-03-23 11:51:00     15.10      sec
# 2            10000032   50853  2180-03-23 11:51:00     15.00    ng/mL
# 3            10000032   50861  2180-03-23 11:51:00    102.00     IU/L
# 4            10000032   50862  2180-03-23 11:51:00      3.30     g/dL
# ...               ...     ...                  ...       ...      ...
# 118171361    19999987   51277  2145-11-09 05:30:00     15.40        %
# 118171362    19999987   51279  2145-11-09 05:30:00      3.52     m/uL
# 118171363    19999987   51301  2145-11-09 05:30:00      5.70     K/uL
# 118171364    19999987   50912  2146-02-07 11:13:00      1.10    mg/dL
# 118171366    19999987   51006  2146-02-07 11:13:00     14.00    mg/dL
#
#            ref_range_lower  ref_range_upper
# 0                      0.9              1.1
# 1                      9.4             12.5
# 2                     30.0             60.0
# 3                      0.0             40.0
# 4                      3.5              5.2
# ...                    ...              ...
# 118171361             10.5             15.5
# 118171362              4.2              5.4
# 118171363              4.0             11.0
# 118171364              0.4              1.1
# 118171366              6.0             20.0
#
# [101102206 rows x 7 columns]

# %% [markdown]
# ## Save

# %%
# summary_lab.to_csv('summary/summary_lab.csv',index = False)
# summary_chart.to_csv('summary/summary_chart.csv',index = False)
# summary_procedures.to_csv('summary/summary_procedures.csv',index = False,sep = ';')
summary_prescriptions.to_csv('summary/summary_prescriptions_.csv',index = False,sep = ';')
# summary_microbiology.to_csv('summary/summary_microbiology.csv',index = False,sep = ';')
# summary_omr.to_csv('summary/summary_omr.csv',index = False)
